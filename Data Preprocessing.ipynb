# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('data/SICK_test.txt', sep='\t')
df
# Out:
#       pair_ID                                         sentence_A  \
# 0           6  There is no boy playing outdoors and there is ...
# 1           7  A group of boys in a yard is playing and a man...
# 2           8  A group of children is playing in the house an...
# 3          10  A brown dog is attacking another animal in fro...
# 4          11  A brown dog is attacking another animal in fro...
# ...       ...                                                ...
# 4922     9991    The young girl is blowing a bubble that is huge
# 4923     9992  A dog in a colored coat is running across the ...
# 4924     9994                 A boy is happily playing the piano
# 4925     9995  The girl , who is little , is combing her hair...
# 4926     9996  A man is in a parking lot and is playing tenni...
#
#                                              sentence_B  relatedness_score  \
# 0     A group of kids is playing in a yard and an ol...              3.300
# 1     The young boys are playing outdoors and the ma...              3.700
# 2     The young boys are playing outdoors and the ma...              3.000
# 3     A brown dog is attacking another animal in fro...              4.900
# 4     A brown dog is helping another animal in front...              3.665
# ...                                                 ...                ...
# 4922         There is no girl in pink twirling a ribbon              2.100
# 4923               The flute is being played by one man              1.000
# 4924       A white bird is landing swiftly in the water              1.000
# 4925  Two people wearing helmets are driving over th...              1.000
# 4926  The snowboarder is leaping fearlessly over whi...              1.000
#
#      entailment_judgment
# 0                NEUTRAL
# 1                NEUTRAL
# 2                NEUTRAL
# 3             ENTAILMENT
# 4                NEUTRAL
# ...                  ...
# 4922             NEUTRAL
# 4923             NEUTRAL
# 4924             NEUTRAL
# 4925             NEUTRAL
# 4926             NEUTRAL
#
# [4927 rows x 5 columns]

# %%
np.unique(df['entailment_judgment'])
# Out:
# array(['CONTRADICTION', 'ENTAILMENT', 'NEUTRAL'], dtype=object)

# %%
df.loc[2]
# Out:
# pair_ID                                                                3
# sentence_A             The young boys are playing outdoors and the ma...
# sentence_B             The kids are playing outdoors near a man with ...
# relatedness_score                                                    4.7
# entailment_judgment                                           ENTAILMENT
# Name: 2, dtype: object

# %%
df.loc[37]
# Out:
# pair_ID                                                 90
# sentence_A             A man is jumping into an empty pool
# sentence_B               A man is jumping into a full pool
# relatedness_score                                      3.0
# entailment_judgment                          CONTRADICTION
# Name: 37, dtype: object

# %%
import re

def text_cleaner(text):
    newString = text.lower()
    newString = re.sub(r'\([^)]*\)', '', newString)
    newString = re.sub('"','', newString)
    newString = re.sub(r"'s\b","",newString)
    newString = re.sub("[^a-zA-Z]", " ", newString) 
    newString = re.sub('[m]{2,}', 'mm', newString) 
    return newString.strip()

# %%
df['sentence_A'] = df['sentence_A'].apply(lambda x: text_cleaner(x))
df['sentence_B'] = df['sentence_B'].apply(lambda x: text_cleaner(x))
df
# Out:
#       pair_ID                                         sentence_A  \
# 0           6  there is no boy playing outdoors and there is ...
# 1           7  a group of boys in a yard is playing and a man...
# 2           8  a group of children is playing in the house an...
# 3          10  a brown dog is attacking another animal in fro...
# 4          11  a brown dog is attacking another animal in fro...
# ...       ...                                                ...
# 4922     9991    the young girl is blowing a bubble that is huge
# 4923     9992  a dog in a colored coat is running across the ...
# 4924     9994                 a boy is happily playing the piano
# 4925     9995  the girl   who is little   is combing her hair...
# 4926     9996  a man is in a parking lot and is playing tenni...
#
#                                              sentence_B  relatedness_score  \
# 0     a group of kids is playing in a yard and an ol...              3.300
# 1     the young boys are playing outdoors and the ma...              3.700
# 2     the young boys are playing outdoors and the ma...              3.000
# 3     a brown dog is attacking another animal in fro...              4.900
# 4     a brown dog is helping another animal in front...              3.665
# ...                                                 ...                ...
# 4922         there is no girl in pink twirling a ribbon              2.100
# 4923               the flute is being played by one man              1.000
# 4924       a white bird is landing swiftly in the water              1.000
# 4925  two people wearing helmets are driving over th...              1.000
# 4926  the snowboarder is leaping fearlessly over whi...              1.000
#
#      entailment_judgment
# 0                NEUTRAL
# 1                NEUTRAL
# 2                NEUTRAL
# 3             ENTAILMENT
# 4                NEUTRAL
# ...                  ...
# 4922             NEUTRAL
# 4923             NEUTRAL
# 4924             NEUTRAL
# 4925             NEUTRAL
# 4926             NEUTRAL
#
# [4927 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['entailment_judgment'])
df['target'] = le.transform(df['entailment_judgment'])
df
# Out:
#       pair_ID                                         sentence_A  \
# 0           6  there is no boy playing outdoors and there is ...
# 1           7  a group of boys in a yard is playing and a man...
# 2           8  a group of children is playing in the house an...
# 3          10  a brown dog is attacking another animal in fro...
# 4          11  a brown dog is attacking another animal in fro...
# ...       ...                                                ...
# 4922     9991    the young girl is blowing a bubble that is huge
# 4923     9992  a dog in a colored coat is running across the ...
# 4924     9994                 a boy is happily playing the piano
# 4925     9995  the girl   who is little   is combing her hair...
# 4926     9996  a man is in a parking lot and is playing tenni...
#
#                                              sentence_B  relatedness_score  \
# 0     a group of kids is playing in a yard and an ol...              3.300
# 1     the young boys are playing outdoors and the ma...              3.700
# 2     the young boys are playing outdoors and the ma...              3.000
# 3     a brown dog is attacking another animal in fro...              4.900
# 4     a brown dog is helping another animal in front...              3.665
# ...                                                 ...                ...
# 4922         there is no girl in pink twirling a ribbon              2.100
# 4923               the flute is being played by one man              1.000
# 4924       a white bird is landing swiftly in the water              1.000
# 4925  two people wearing helmets are driving over th...              1.000
# 4926  the snowboarder is leaping fearlessly over whi...              1.000
#
#      entailment_judgment  target
# 0                NEUTRAL       2
# 1                NEUTRAL       2
# 2                NEUTRAL       2
# 3             ENTAILMENT       1
# 4                NEUTRAL       2
# ...                  ...     ...
# 4922             NEUTRAL       2
# 4923             NEUTRAL       2
# 4924             NEUTRAL       2
# 4925             NEUTRAL       2
# 4926             NEUTRAL       2
#
# [4927 rows x 6 columns]

# %%
data_for_training = df[['sentence_A', 'sentence_B', 'target']]
pd.concat([data_for_training, df[:3000][['sentence_A', 'sentence_B', 'target']]], axis=0).to_csv('data/train.csv', index=False)
data_for_training
# Out:
#                                              sentence_A  \
# 0     there is no boy playing outdoors and there is ...
# 1     a group of boys in a yard is playing and a man...
# 2     a group of children is playing in the house an...
# 3     a brown dog is attacking another animal in fro...
# 4     a brown dog is attacking another animal in fro...
# ...                                                 ...
# 4922    the young girl is blowing a bubble that is huge
# 4923  a dog in a colored coat is running across the ...
# 4924                 a boy is happily playing the piano
# 4925  the girl   who is little   is combing her hair...
# 4926  a man is in a parking lot and is playing tenni...
#
#                                              sentence_B  target
# 0     a group of kids is playing in a yard and an ol...       2
# 1     the young boys are playing outdoors and the ma...       2
# 2     the young boys are playing outdoors and the ma...       2
# 3     a brown dog is attacking another animal in fro...       1
# 4     a brown dog is helping another animal in front...       2
# ...                                                 ...     ...
# 4922         there is no girl in pink twirling a ribbon       2
# 4923               the flute is being played by one man       2
# 4924       a white bird is landing swiftly in the water       2
# 4925  two people wearing helmets are driving over th...       2
# 4926  the snowboarder is leaping fearlessly over whi...       2
#
# [4927 rows x 3 columns]

# %%
data_for_test = df[3000:][['sentence_A', 'sentence_B', 'target']]
data_for_test.to_csv('data/test.csv', index=False)
data_for_test
# Out:
#                                              sentence_A  \
# 3000                         a boy and a girl are naked
# 3001  the boy and the girl are cheerfully playing an...
# 3002  the boy and the girl are cheerfully playing an...
# 3003  the boy and the girl are not playing and weari...
# 3004  a boy and a girl in swimsuits are wearing floa...
# ...                                                 ...
# 4922    the young girl is blowing a bubble that is huge
# 4923  a dog in a colored coat is running across the ...
# 4924                 a boy is happily playing the piano
# 4925  the girl   who is little   is combing her hair...
# 4926  a man is in a parking lot and is playing tenni...
#
#                                              sentence_B  target
# 3000  a boy and a girl in swimsuits are wearing arm ...       0
# 3001  the boy and the girl are playing and wearing a...       1
# 3002  a boy and a girl in swimsuits are wearing arm ...       2
# 3003  a boy and a girl in swimsuits are wearing arm ...       2
# 3004  the boy and the girl are playing and wearing a...       2
# ...                                                 ...     ...
# 4922         there is no girl in pink twirling a ribbon       2
# 4923               the flute is being played by one man       2
# 4924       a white bird is landing swiftly in the water       2
# 4925  two people wearing helmets are driving over th...       2
# 4926  the snowboarder is leaping fearlessly over whi...       2
#
# [1927 rows x 3 columns]

# %%
pd.read_csv('data/train.csv')
# Out:
#                                              sentence_A  \
# 0     there is no boy playing outdoors and there is ...
# 1     a group of boys in a yard is playing and a man...
# 2     a group of children is playing in the house an...
# 3     a brown dog is attacking another animal in fro...
# 4     a brown dog is attacking another animal in fro...
# ...                                                 ...
# 7922            two people are wading through the water
# 7923  nobody is standing in the ocean and watching t...
# 7924  two people are standing in the ocean and watch...
# 7925  two people are standing in the ocean and watch...
# 7926  a race car driver is standing up and pointing ...
#
#                                              sentence_B  target
# 0     a group of kids is playing in a yard and an ol...       2
# 1     the young boys are playing outdoors and the ma...       2
# 2     the young boys are playing outdoors and the ma...       2
# 3     a brown dog is attacking another animal in fro...       1
# 4     a brown dog is helping another animal in front...       2
# ...                                                 ...     ...
# 7922    a couple or people are wading through the water       1
# 7923            two people are wading through the water       2
# 7924    a couple or people are wading through the water       2
# 7925            two people are wading through the water       2
# 7926  a person in a blue jacket is wearing a colorfu...       2
#
# [7927 rows x 3 columns]
